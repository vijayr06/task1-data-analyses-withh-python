# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv('global superstore.csv')
type(data)
pd.core.frame.DataFrame
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order ID          20 non-null     object
#  1   Sales ($)         20 non-null     float64
#  2   Profit ($)        20 non-null     float64
#  3   Region            20 non-null     object
#  4   Product Category  20 non-null     object
# dtypes: float64(2), object(3)
# memory usage: 932.0+ bytes

# %%
data.describe()
# Out:
#         Sales ($)  Profit ($)
# count    20.00000   20.000000
# mean    638.67500   90.795000
# std     528.53567  110.454652
# min      45.00000  -50.200000
# 25%     220.10000   10.850000
# 50%     515.52500   50.200000
# 75%    1010.48750  154.312500
# max    1750.90000  320.500000

# %%
data=data.drop_duplicates()
data
# Out:
#      Order ID  Sales ($)  Profit ($)         Region Product Category
# 0   ORD-10001     250.00       35.00  North America  Office Supplies
# 1   ORD-10002    1300.50      200.30         Europe       Technology
# 2   ORD-10003     580.75      -50.20           Asia        Furniture
# 3   ORD-10004     910.40      100.10  South America  Office Supplies
# 4   ORD-10005      60.00        5.00         Europe  Office Supplies
# 5   ORD-10006    1520.00      320.50  North America       Technology
# 6   ORD-10007     240.20       12.80           Asia        Furniture
# 7   ORD-10008      78.90      -10.00         Africa  Office Supplies
# 8   ORD-10009     600.00       80.00  South America        Furniture
# 9   ORD-10010    1100.75      250.25         Europe       Technology
# 10  ORD-10011     450.30       60.40  North America  Office Supplies
# 11  ORD-10012    1750.90      310.00           Asia       Technology
# 12  ORD-10013      90.00       15.00         Africa        Furniture
# 13  ORD-10014    1220.00      180.00         Europe       Technology
# 14  ORD-10015     335.60      -25.00  South America        Furniture
# 15  ORD-10016      45.00        3.50         Africa  Office Supplies
# 16  ORD-10017     980.40      145.75  North America       Technology
# 17  ORD-10018     300.00       40.00           Asia  Office Supplies
# 18  ORD-10019     159.80       22.50         Europe        Furniture
# 19  ORD-10020     800.00      120.00  South America       Technology

# %%
data.isnull()
# Out:
#     Order ID  Sales ($)  Profit ($)  Region  Product Category
# 0      False      False       False   False             False
# 1      False      False       False   False             False
# 2      False      False       False   False             False
# 3      False      False       False   False             False
# 4      False      False       False   False             False
# 5      False      False       False   False             False
# 6      False      False       False   False             False
# 7      False      False       False   False             False
# 8      False      False       False   False             False
# 9      False      False       False   False             False
# 10     False      False       False   False             False
# 11     False      False       False   False             False
# 12     False      False       False   False             False
# 13     False      False       False   False             False
# 14     False      False       False   False             False
# 15     False      False       False   False             False
# 16     False      False       False   False             False
# 17     False      False       False   False             False
# 18     False      False       False   False             False
# 19     False      False       False   False             False

# %%
data.isnull().sum()
# Out:
# Order ID            0
# Sales ($)           0
# Profit ($)          0
# Region              0
# Product Category    0
# dtype: int64

# %%
data.notnull()
# Out:
#     Order ID  Sales ($)  Profit ($)  Region  Product Category
# 0       True       True        True    True              True
# 1       True       True        True    True              True
# 2       True       True        True    True              True
# 3       True       True        True    True              True
# 4       True       True        True    True              True
# 5       True       True        True    True              True
# 6       True       True        True    True              True
# 7       True       True        True    True              True
# 8       True       True        True    True              True
# 9       True       True        True    True              True
# 10      True       True        True    True              True
# 11      True       True        True    True              True
# 12      True       True        True    True              True
# 13      True       True        True    True              True
# 14      True       True        True    True              True
# 15      True       True        True    True              True
# 16      True       True        True    True              True
# 17      True       True        True    True              True
# 18      True       True        True    True              True
# 19      True       True        True    True              True

# %%
data2=data.fillna(value=0)
data2
# Out:
#      Order ID  Sales ($)  Profit ($)         Region Product Category
# 0   ORD-10001     250.00       35.00  North America  Office Supplies
# 1   ORD-10002    1300.50      200.30         Europe       Technology
# 2   ORD-10003     580.75      -50.20           Asia        Furniture
# 3   ORD-10004     910.40      100.10  South America  Office Supplies
# 4   ORD-10005      60.00        5.00         Europe  Office Supplies
# 5   ORD-10006    1520.00      320.50  North America       Technology
# 6   ORD-10007     240.20       12.80           Asia        Furniture
# 7   ORD-10008      78.90      -10.00         Africa  Office Supplies
# 8   ORD-10009     600.00       80.00  South America        Furniture
# 9   ORD-10010    1100.75      250.25         Europe       Technology
# 10  ORD-10011     450.30       60.40  North America  Office Supplies
# 11  ORD-10012    1750.90      310.00           Asia       Technology
# 12  ORD-10013      90.00       15.00         Africa        Furniture
# 13  ORD-10014    1220.00      180.00         Europe       Technology
# 14  ORD-10015     335.60      -25.00  South America        Furniture
# 15  ORD-10016      45.00        3.50         Africa  Office Supplies
# 16  ORD-10017     980.40      145.75  North America       Technology
# 17  ORD-10018     300.00       40.00           Asia  Office Supplies
# 18  ORD-10019     159.80       22.50         Europe        Furniture
# 19  ORD-10020     800.00      120.00  South America       Technology

# %%
data3=data.ffill()
data
# Out:
#      Order ID  Sales ($)  Profit ($)         Region Product Category
# 0   ORD-10001     250.00       35.00  North America  Office Supplies
# 1   ORD-10002    1300.50      200.30         Europe       Technology
# 2   ORD-10003     580.75      -50.20           Asia        Furniture
# 3   ORD-10004     910.40      100.10  South America  Office Supplies
# 4   ORD-10005      60.00        5.00         Europe  Office Supplies
# 5   ORD-10006    1520.00      320.50  North America       Technology
# 6   ORD-10007     240.20       12.80           Asia        Furniture
# 7   ORD-10008      78.90      -10.00         Africa  Office Supplies
# 8   ORD-10009     600.00       80.00  South America        Furniture
# 9   ORD-10010    1100.75      250.25         Europe       Technology
# 10  ORD-10011     450.30       60.40  North America  Office Supplies
# 11  ORD-10012    1750.90      310.00           Asia       Technology
# 12  ORD-10013      90.00       15.00         Africa        Furniture
# 13  ORD-10014    1220.00      180.00         Europe       Technology
# 14  ORD-10015     335.60      -25.00  South America        Furniture
# 15  ORD-10016      45.00        3.50         Africa  Office Supplies
# 16  ORD-10017     980.40      145.75  North America       Technology
# 17  ORD-10018     300.00       40.00           Asia  Office Supplies
# 18  ORD-10019     159.80       22.50         Europe        Furniture
# 19  ORD-10020     800.00      120.00  South America       Technology

# %%
data4=data.bfill()
data4
# Out:
#      Order ID  Sales ($)  Profit ($)         Region Product Category
# 0   ORD-10001     250.00       35.00  North America  Office Supplies
# 1   ORD-10002    1300.50      200.30         Europe       Technology
# 2   ORD-10003     580.75      -50.20           Asia        Furniture
# 3   ORD-10004     910.40      100.10  South America  Office Supplies
# 4   ORD-10005      60.00        5.00         Europe  Office Supplies
# 5   ORD-10006    1520.00      320.50  North America       Technology
# 6   ORD-10007     240.20       12.80           Asia        Furniture
# 7   ORD-10008      78.90      -10.00         Africa  Office Supplies
# 8   ORD-10009     600.00       80.00  South America        Furniture
# 9   ORD-10010    1100.75      250.25         Europe       Technology
# 10  ORD-10011     450.30       60.40  North America  Office Supplies
# 11  ORD-10012    1750.90      310.00           Asia       Technology
# 12  ORD-10013      90.00       15.00         Africa        Furniture
# 13  ORD-10014    1220.00      180.00         Europe       Technology
# 14  ORD-10015     335.60      -25.00  South America        Furniture
# 15  ORD-10016      45.00        3.50         Africa  Office Supplies
# 16  ORD-10017     980.40      145.75  North America       Technology
# 17  ORD-10018     300.00       40.00           Asia  Office Supplies
# 18  ORD-10019     159.80       22.50         Europe        Furniture
# 19  ORD-10020     800.00      120.00  South America       Technology

# %%
import numpy as np
from scipy import stats
data2.columns
# Out:
# Index(['Order ID', 'Sales ($)', 'Profit ($)', 'Region', 'Product Category'], dtype='object')

# %%
data2.drop(['Order ID','Region','Product Category'],axis=1,inplace=True)
data2.columns
# Out:
# Index(['Sales ($)', 'Profit ($)'], dtype='object')

# %%
Q1=data2.quantile(0.25)
Q3=data2.quantile(0.75)
IQR=Q3-Q1
print(IQR)
# Out:
# Sales ($)     790.3875
# Profit ($)    143.4625
# dtype: float64

# %%
data2=data2[~((data2<(Q1-1.5*IQR))|(data2>(Q3+1.5*IQR))).any(axis=1)]
data2
# Out:
#     Sales ($)  Profit ($)
# 0      250.00       35.00
# 1     1300.50      200.30
# 2      580.75      -50.20
# 3      910.40      100.10
# 4       60.00        5.00
# 5     1520.00      320.50
# 6      240.20       12.80
# 7       78.90      -10.00
# 8      600.00       80.00
# 9     1100.75      250.25
# 10     450.30       60.40
# 11    1750.90      310.00
# 12      90.00       15.00
# 13    1220.00      180.00
# 14     335.60      -25.00
# 15      45.00        3.50
# 16     980.40      145.75
# 17     300.00       40.00
# 18     159.80       22.50
# 19     800.00      120.00

# %%
data2.describe()
# Out:
#         Sales ($)  Profit ($)
# count    20.00000   20.000000
# mean    638.67500   90.795000
# std     528.53567  110.454652
# min      45.00000  -50.200000
# 25%     220.10000   10.850000
# 50%     515.52500   50.200000
# 75%    1010.48750  154.312500
# max    1750.90000  320.500000

# %%
plt.figure(figsize=(8,5))
plt.hist(data[['Sales ($)','Profit ($)']], bins=10, color=['skyblue','lightgreen'], edgecolor='black')
plt.title("Distribution of Sales and Profit")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.show()

# %%
print(data.columns)
# Out:
# Index(['Order ID', 'Sales ($)', 'Profit ($)', 'Region', 'Product Category'], dtype='object')

# %%
plt.figure(figsize=(12,6))
plt.subplot(1, 2, 1)
sns.boxplot(y=data['Sales ($)'])
plt.title('Boxplot of Sales')
plt.subplot(1, 2, 2)
sns.boxplot(y=data['Profit ($)'])
plt.show()

# %%
plt.figure(figsize=(8,6))
numeric_cols = data.select_dtypes(include=['float64', 'int64']).columns
corr = data[numeric_cols].corr()
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title("Correlation Heatmap of Numeric Features")
plt.show()
